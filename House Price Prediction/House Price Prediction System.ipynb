# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv('nigeria_houses_data.csv')
df
# Out:
#        bedrooms  bathrooms  toilets  parking_space                 title  \
# 0           6.0        5.0      5.0            4.0       Detached Duplex
# 1           4.0        5.0      5.0            4.0     Terraced Duplexes
# 2           4.0        5.0      5.0            4.0       Detached Duplex
# 3           4.0        4.0      5.0            6.0       Detached Duplex
# 4           4.0        4.0      5.0            2.0  Semi Detached Duplex
# ...         ...        ...      ...            ...                   ...
# 24321       2.0        2.0      2.0            4.0        Block of Flats
# 24322       4.0        5.0      5.0            4.0        Block of Flats
# 24323       4.0        5.0      5.0            4.0       Detached Duplex
# 24324       3.0        4.0      4.0            3.0        Block of Flats
# 24325       4.0        5.0      5.0            4.0       Detached Duplex
#
#                        town  state        price
# 0                   Mabushi  Abuja  450000000.0
# 1                   Katampe  Abuja  800000000.0
# 2                     Lekki  Lagos  120000000.0
# 3                      Ajah  Lagos   40000000.0
# 4                     Lekki  Lagos   75000000.0
# ...                     ...    ...          ...
# 24321                Kabusa  Abuja   15000000.0
# 24322           Ado-Odo/Ota   Ogun   25000000.0
# 24323                 Lekki  Lagos   68000000.0
# 24324  Victoria Island (VI)  Lagos   78000000.0
# 24325                 Lekki  Lagos   65000000.0
#
# [24326 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24326 entries, 0 to 24325
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       24326 non-null  float64
#  1   bathrooms      24326 non-null  float64
#  2   toilets        24326 non-null  float64
#  3   parking_space  24326 non-null  float64
#  4   title          24326 non-null  str
#  5   town           24326 non-null  str
#  6   state          24326 non-null  str
#  7   price          24326 non-null  float64
# dtypes: float64(5), str(3)
# memory usage: 2.1 MB

# %%
df.describe()
# Out:
#            bedrooms     bathrooms       toilets  parking_space         price
# count  24326.000000  24326.000000  24326.000000   24326.000000  2.432600e+04
# mean       4.338814      4.600798      5.176355       4.041725  3.013802e+08
# std        1.138497      1.163161      1.226253       1.399936  1.220403e+10
# min        1.000000      1.000000      1.000000       1.000000  9.000000e+04
# 25%        4.000000      4.000000      5.000000       4.000000  5.200000e+07
# 50%        4.000000      5.000000      5.000000       4.000000  8.500000e+07
# 75%        5.000000      5.000000      6.000000       4.000000  1.600000e+08
# max        9.000000      9.000000      9.000000       9.000000  1.800000e+12

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['price'], bins=50)
plt.xlabel('Price (₦)')
plt.ylabel('Number of houses')
plt.title('Distribution of House Prices (raw, with outliers)')
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x="bedrooms", y="price")

plt.title("House Price vs Number of Bedrooms")
plt.xlabel("Number of Bedrooms")
plt.ylabel("Price")

plt.show()

# %%
df.sort_values('price', ascending=False).head(10)
# Out:
#        bedrooms  bathrooms  toilets  parking_space                 title  \
# 4096        7.0        7.0      8.0            8.0       Detached Duplex
# 6632        4.0        4.0      5.0            4.0  Semi Detached Duplex
# 15962       9.0        9.0      1.0            4.0       Detached Duplex
# 4327        5.0        5.0      6.0            4.0       Detached Duplex
# 7098        5.0        5.0      6.0            4.0  Semi Detached Duplex
# 15836       5.0        6.0      7.0            4.0     Terraced Duplexes
# 15806       5.0        5.0      5.0            1.0       Detached Duplex
# 17383       4.0        4.0      5.0            3.0       Detached Duplex
# 13490       3.0        3.0      3.0            4.0  Semi Detached Duplex
# 20602       4.0        5.0      5.0            4.0        Block of Flats
#
#                   town  state         price
# 4096             Ikoyi  Lagos  1.800000e+12
# 6632             Ikoyi  Lagos  4.500000e+11
# 15962            Lekki  Lagos  3.500000e+11
# 4327             Lekki  Lagos  1.600000e+11
# 7098             Lekki  Lagos  1.250000e+11
# 15836  Guzape District  Abuja  8.500000e+10
# 15806     Ifako-Ijaiye  Lagos  5.500000e+10
# 17383             Ajah  Lagos  5.000000e+10
# 13490             Ajah  Lagos  4.200000e+10
# 20602            Ikoyi  Lagos  1.500000e+10

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower bound: {lower_bound:,.0f}")
print(f"Upper bound: {upper_bound:,.0f}")

outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
print(f"Number of outliers: {len(outliers)}")
# Out:
# Lower bound: -110,000,000
# Upper bound: 322,000,000
# Number of outliers: 2558

# %%
df.sort_values('price', ascending=False).head(30)
# Out:
#        bedrooms  bathrooms  toilets  parking_space                 title  \
# 4096        7.0        7.0      8.0            8.0       Detached Duplex
# 6632        4.0        4.0      5.0            4.0  Semi Detached Duplex
# 15962       9.0        9.0      1.0            4.0       Detached Duplex
# 4327        5.0        5.0      6.0            4.0       Detached Duplex
# 7098        5.0        5.0      6.0            4.0  Semi Detached Duplex
# 15836       5.0        6.0      7.0            4.0     Terraced Duplexes
# 15806       5.0        5.0      5.0            1.0       Detached Duplex
# 17383       4.0        4.0      5.0            3.0       Detached Duplex
# 13490       3.0        3.0      3.0            4.0  Semi Detached Duplex
# 20602       4.0        5.0      5.0            4.0        Block of Flats
# 17045       3.0        3.0      4.0            4.0     Detached Bungalow
# 504         4.0        5.0      5.0            4.0        Block of Flats
# 23444       4.0        5.0      5.0            4.0        Block of Flats
# 2358        1.0        1.0      1.0            4.0       Detached Duplex
# 2570        4.0        5.0      5.0            4.0        Block of Flats
# 14398       4.0        5.0      5.0            4.0        Block of Flats
# 13783       4.0        4.0      5.0            4.0        Block of Flats
# 22531       5.0        5.0      5.0            4.0       Detached Duplex
# 7345        3.0        3.0      4.0            4.0        Block of Flats
# 22865       5.0        5.0      6.0            4.0       Detached Duplex
# 21291       5.0        5.0      5.0            8.0       Detached Duplex
# 19861       4.0        5.0      5.0            4.0        Block of Flats
# 6083        4.0        5.0      5.0            4.0        Block of Flats
# 1000        5.0        5.0      5.0            4.0        Block of Flats
# 13122       5.0        6.0      6.0            4.0        Block of Flats
# 13181       5.0        6.0      6.0            6.0       Detached Duplex
# 15881       5.0        5.0      7.0            6.0       Detached Duplex
# 14347       4.0        5.0      5.0            4.0        Block of Flats
# 11598       6.0        6.0      7.0            6.0       Detached Duplex
# 10052       7.0        7.0      8.0            4.0       Detached Duplex
#
#                        town   state         price
# 4096                  Ikoyi   Lagos  1.800000e+12
# 6632                  Ikoyi   Lagos  4.500000e+11
# 15962                 Lekki   Lagos  3.500000e+11
# 4327                  Lekki   Lagos  1.600000e+11
# 7098                  Lekki   Lagos  1.250000e+11
# 15836       Guzape District   Abuja  8.500000e+10
# 15806          Ifako-Ijaiye   Lagos  5.500000e+10
# 17383                  Ajah   Lagos  5.000000e+10
# 13490                  Ajah   Lagos  4.200000e+10
# 20602                 Ikoyi   Lagos  1.500000e+10
# 17045           Ibeju Lekki   Lagos  1.500000e+10
# 504                   Ikoyi   Lagos  1.500000e+10
# 23444                 Ikoyi   Lagos  1.500000e+10
# 2358                Katampe   Abuja  1.500000e+10
# 2570                  Ikoyi   Lagos  1.400000e+10
# 14398                 Ikoyi   Lagos  1.300000e+10
# 13783                 Ikoyi   Lagos  1.050000e+10
# 22531               Katampe   Abuja  9.000000e+09
# 7345                  Ikoyi   Lagos  8.500000e+09
# 22865               Katampe   Abuja  8.000000e+09
# 21291                 Ikoyi   Lagos  7.500000e+09
# 19861                 Ikoyi   Lagos  6.700000e+09
# 6083   Victoria Island (VI)   Lagos  6.000000e+09
# 1000              Life Camp   Abuja  4.000000e+09
# 13122                 Ikoyi   Lagos  4.000000e+09
# 13181         Port Harcourt  Rivers  4.000000e+09
# 15881                 Ikoyi   Lagos  4.000000e+09
# 14347                 Ikoyi   Lagos  4.000000e+09
# 11598                 Ikoyi   Lagos  4.000000e+09
# 10052                 Ikoyi   Lagos  4.000000e+09

# %%
df_clean = df[df['price'] < 25_000_000_000].copy()
print(f"Removed {len(df) - len(df_clean)} rows")
df_clean['price'].describe()
# Out:
# Removed 9 rows
# count    2.431700e+04
# mean     1.733098e+08
# std      3.881701e+08
# min      9.000000e+04
# 25%      5.200000e+07
# 50%      8.500000e+07
# 75%      1.600000e+08
# max      1.500000e+10
# Name: price, dtype: float64

# %%
town_counts = df_clean['town'].value_counts()
common_towns = town_counts[town_counts >= 50].index
df_clean['town_grouped'] = df_clean['town'].apply(lambda t: t if t in common_towns else 'Other')

# %%
plt.figure(figsize=(8,5))
plt.hist(df_clean['price'], bins=50)
plt.xlabel('Price (₦)')
plt.ylabel('Number of houses')
plt.title('Distribution of House Prices (cleaned)')
plt.show()

# %%
df_model = df_clean.drop(columns=['town'])
df_encoded = pd.get_dummies(df_model, columns=['title', 'state', 'town_grouped'], drop_first=True)

# %%
X = df_encoded.drop(columns=['price'])
y = np.log(df_encoded['price'])

# %%
import numpy as np

plt.figure(figsize=(8,5))
plt.hist(np.log(df_clean['price']), bins=50)
plt.xlabel('Log(Price)')
plt.ylabel('Number of houses')
plt.title('Distribution of Log-Transformed House Prices')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('R2:', r2_score(y_test, y_pred))
# Out:
# R2: 0.65640545125403

# %%
df_model
# Out:
#        bedrooms  bathrooms  toilets  parking_space                 title  \
# 0           6.0        5.0      5.0            4.0       Detached Duplex
# 1           4.0        5.0      5.0            4.0     Terraced Duplexes
# 2           4.0        5.0      5.0            4.0       Detached Duplex
# 3           4.0        4.0      5.0            6.0       Detached Duplex
# 4           4.0        4.0      5.0            2.0  Semi Detached Duplex
# ...         ...        ...      ...            ...                   ...
# 24321       2.0        2.0      2.0            4.0        Block of Flats
# 24322       4.0        5.0      5.0            4.0        Block of Flats
# 24323       4.0        5.0      5.0            4.0       Detached Duplex
# 24324       3.0        4.0      4.0            3.0        Block of Flats
# 24325       4.0        5.0      5.0            4.0       Detached Duplex
#
#        state        price          town_grouped
# 0      Abuja  450000000.0               Mabushi
# 1      Abuja  800000000.0               Katampe
# 2      Lagos  120000000.0                 Lekki
# 3      Lagos   40000000.0                  Ajah
# 4      Lagos   75000000.0                 Lekki
# ...      ...          ...                   ...
# 24321  Abuja   15000000.0                 Other
# 24322   Ogun   25000000.0                 Other
# 24323  Lagos   68000000.0                 Lekki
# 24324  Lagos   78000000.0  Victoria Island (VI)
# 24325  Lagos   65000000.0                 Lekki
#
# [24317 rows x 8 columns]
